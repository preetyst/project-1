# %% [markdown]
# # By Shrestha Madan and Shrestha Preety (2nd part visualization)

# %%
import pandas as pd   # importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
MAC270 = pd.read_table('chipotle.tsv') # importing files from downloads

# %%
MAC270
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
MAC270.head(5)  #showing first 5 columns
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
import matplotlib.pyplot as plt

# %%
items = MAC270.item_name.value_counts()[:5].plot(kind ='hist')  # creating histogram of top 5 selling products

# %%
items = MAC270.item_name.value_counts().plot
plt.scatter(MAC270['quantity'],MAC270['item_price'])    # creating scatter plot for number of items ordered per price
fig= plt.figure(figsize= (13,7), dpi=500)

# %% [markdown]
# # What is the least selling item among chicken bowl? (Bonus)

# %%
descriptions = MAC270.groupby(['item_name','choice_description'])['order_id'].count().reset_index(name = 'count')

# %%
descriptions = descriptions[descriptions['item_name'].str.contains('Chicken Bowl')]

# %%
descriptions.sort_values(['count'],ascending= True)[:1]
# Out:
#         item_name                        choice_description  count
# 329  Chicken Bowl  [Fresh Tomato (Mild), [Guacamole, Rice]]      1
