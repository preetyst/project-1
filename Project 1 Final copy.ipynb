# %% [markdown]
# # Project 1 : PREETY and MADAN SHRESTHA's GROUP PROJECT

# %%
# 1. Import the necessary libraries

#importing libraries 
import pandas as pd
import numpy as np

# %%
 # 2. Create a DataFrame with dictionary. Your DataFrame should contains at
# least 20 rows and 6 columns. In some cells, include standard,
# non-standard, and expected missing values.

# %%
#3. Assign your DataFrame to a variable called your MAC270

# MAC270 is the variable. Keys and values are also listed.
MAC270 = {'Employees_sales': ['Jones', 'Alpha', 'charlie','delta','Madan','sujan','Rajan','preety','Nanu','Gautam','urmila','rosy','yogen',
                    'peter','prekshya','basanta','sudan','bipin','padam','hommodi'],
         'Jan': [10, 2, 5, 4, 5, 5, None, None,3,6,5,7,9,8,5,5,6,8,9,None],
         'Feb': [20, 2, 'Unexp', 4, 5, 5, None,7,7,9,8,8,8,8,1,7,7,9,6,8],
         'Mar': [14, None, 9, 6, 8, 8, None,5,6,7,8,9,9,9,9,9,8,7,8,None],
        'April': [None,3, None, 9,8,4,5,7,6,9,8,9,8, None,7,6,7,8,9,6],
        'May':[None,4,5,7,7, None,6,7,6,9,7,9,8,8,7,7,9,8,7,7]}

# %%
#calling
MAC270 = pd.DataFrame.from_dict(MAC270)
#printing data frame
MAC270
# Out:
#    Employees_sales   Jan    Feb   Mar  April  May
# 0            Jones  10.0     20  14.0    NaN  NaN
# 1            Alpha   2.0      2   NaN    3.0  4.0
# 2          charlie   5.0  Unexp   9.0    NaN  5.0
# 3            delta   4.0      4   6.0    9.0  7.0
# 4            Madan   5.0      5   8.0    8.0  7.0
# 5            sujan   5.0      5   8.0    4.0  NaN
# 6            Rajan   NaN   None   NaN    5.0  6.0
# 7           preety   NaN      7   5.0    7.0  7.0
# 8             Nanu   3.0      7   6.0    6.0  6.0
# 9           Gautam   6.0      9   7.0    9.0  9.0
# 10          urmila   5.0      8   8.0    8.0  7.0
# 11            rosy   7.0      8   9.0    9.0  9.0
# 12           yogen   9.0      8   9.0    8.0  8.0
# 13           peter   8.0      8   9.0    NaN  8.0
# 14        prekshya   5.0      1   9.0    7.0  7.0
# 15         basanta   5.0      7   9.0    6.0  7.0
# 16           sudan   6.0      7   8.0    7.0  9.0
# 17           bipin   8.0      9   7.0    8.0  8.0
# ...

# %%
#4. Show how many rows and how many columns
#It shows the number of rows and columns
MAC270.shape
# Out:
# (20, 6)

# %%
# 5. Show only the name of your columns
# giving command to separate columns by semicolon
for col in MAC270:
    print (col, end='; ')
# Out:
# Employees_sales; Jan; Feb; Mar; April; May;

# %%
# 6. Show only the name of your rows

for row in MAC270:
    print (row, end=', ')
# Out:
# Employees_sales, Jan, Feb, Mar, April, May,

# %%
# # 7. Show only the three first rows
#printing first 3 rows only
for row in MAC270.head(3).itertuples():
    print (row)
# Out:
# Pandas(Index=0, Employees_sales='Jones', Jan=10.0, Feb=20, Mar=14.0, April=nan, May=nan)
# Pandas(Index=1, Employees_sales='Alpha', Jan=2.0, Feb=2, Mar=nan, April=3.0, May=4.0)
# Pandas(Index=2, Employees_sales='charlie', Jan=5.0, Feb='Unexp', Mar=9.0, April=nan, May=5.0)

# %%
# # 8. Show the last rows of your DataFrame
#printing last three rows only
MAC270.tail(3)
# Out:
#    Employees_sales  Jan Feb  Mar  April  May
# 17           bipin  8.0   9  7.0    8.0  8.0
# 18           padam  9.0   6  8.0    9.0  7.0
# 19         hommodi  NaN   8  NaN    6.0  7.0

# %%
# 9. Add another column call it new_col and insert what you see appropriate
#    with your dictionary data
#Adding new_col as additional column
MAC270 = {'Employees_sales': ['Jones', 'Alpha', 'charlie','delta','Madan','sujan','Rajan','preety','Nanu','Gautam','urmila','rosy','yogen',
                    'peter','prekshya','basanta','sudan','bipin','padam','hommodi'],
         'Jan': [10, 2, 5, 4, 5, 5, None, None,3,6,5,7,9,8,5,5,6,8,9,None],
         'Feb': [20, 2, 'Unexp', 4, 5, 5, None,7,7,9,8,8,8,8,1,7,7,9,6,8],
         'Mar': [14, None, 9, 6, 8, 8, None,5,6,7,8,9,9,9,9,9,8,7,8,None],
        'April': [None,3, None, 9,8,4,5,7,6,9,8,9,8, None,7,6,7,8,9,6],
        'May':[None,4,5,7,7, None,6,7,6,9,7,9,8,8,7,7,9,8,7,7],
         'new_col':[ 12,3,5,7,5,5,8,6,5,7,8,8,8,7,5,5,7,6,4,6]}
MAC270 = pd.DataFrame.from_dict(MAC270)
MAC270
# Out:
#    Employees_sales   Jan    Feb   Mar  April  May  new_col
# 0            Jones  10.0     20  14.0    NaN  NaN       12
# 1            Alpha   2.0      2   NaN    3.0  4.0        3
# 2          charlie   5.0  Unexp   9.0    NaN  5.0        5
# 3            delta   4.0      4   6.0    9.0  7.0        7
# 4            Madan   5.0      5   8.0    8.0  7.0        5
# 5            sujan   5.0      5   8.0    4.0  NaN        5
# 6            Rajan   NaN   None   NaN    5.0  6.0        8
# 7           preety   NaN      7   5.0    7.0  7.0        6
# 8             Nanu   3.0      7   6.0    6.0  6.0        5
# 9           Gautam   6.0      9   7.0    9.0  9.0        7
# 10          urmila   5.0      8   8.0    8.0  7.0        8
# 11            rosy   7.0      8   9.0    9.0  9.0        8
# 12           yogen   9.0      8   9.0    8.0  8.0        8
# 13           peter   8.0      8   9.0    NaN  8.0        7
# 14        prekshya   5.0      1   9.0    7.0  7.0        5
# ...

# %%
# 10.Present the type of each column
#printing individual columns and showing its data type

MAC270.dtypes
# Out:
# Employees_sales     object
# Jan                float64
# Feb                 object
# Mar                float64
# April              float64
# May                float64
# new_col              int64
# dtype: object

# %%
# 11.Drop the column you added
#dropping the newly added column with function drop
MAC270.drop(columns=[ 'new_col'])
# Out:
#    Employees_sales   Jan    Feb   Mar  April  May
# 0            Jones  10.0     20  14.0    NaN  NaN
# 1            Alpha   2.0      2   NaN    3.0  4.0
# 2          charlie   5.0  Unexp   9.0    NaN  5.0
# 3            delta   4.0      4   6.0    9.0  7.0
# 4            Madan   5.0      5   8.0    8.0  7.0
# 5            sujan   5.0      5   8.0    4.0  NaN
# 6            Rajan   NaN   None   NaN    5.0  6.0
# 7           preety   NaN      7   5.0    7.0  7.0
# 8             Nanu   3.0      7   6.0    6.0  6.0
# 9           Gautam   6.0      9   7.0    9.0  9.0
# 10          urmila   5.0      8   8.0    8.0  7.0
# 11            rosy   7.0      8   9.0    9.0  9.0
# 12           yogen   9.0      8   9.0    8.0  8.0
# 13           peter   8.0      8   9.0    NaN  8.0
# 14        prekshya   5.0      1   9.0    7.0  7.0
# 15         basanta   5.0      7   9.0    6.0  7.0
# 16           sudan   6.0      7   8.0    7.0  9.0
# 17           bipin   8.0      9   7.0    8.0  8.0
# ...

# %% [markdown]
# # How is the performance of employees on first month? Can we show it by graph?  (Bonus)

# %%
# 12.BONUS: Create a question and a graph to answer your own question.

import matplotlib.pyplot as plt
MAC270 = {'Employees_sales': ['Jones', 'Alpha', 'charlie','delta','Madan','sujan','Rajan','preety','Nanu','Gautam','urmila','rosy','yogen',
                    'peter','prekshya','basanta','sudan','bipin','padam','hommodi'],
         'Jan': [10, 2, 5, 4, 5, 5, None, None,3,6,5,7,9,8,5,5,6,8,9,None]}

#plotting the graph for 1st month performance of employees

plt.plot (MAC270['Employees_sales'], MAC270['Jan'])
